# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import model
import pickle
import itertools
# %matplotlib inline

# %%
import importlib
aa = importlib.reload(model)

# %%
# prep_dataaa = model.data_and_network_prep()

# %%
# model.create_data_for_fit(prep_dataaa, 0.35)

# %%
best = model.fit()
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 181/181 [00:19<00:00,  9.35it/s]
# ...
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 181/181 [00:19<00:00,  9.24it/s]

# %%
best
# Out:
#  final_simplex: (array([[0.00051019, 0.01935242, 0.35120681, 0.36533023],
#        [0.00051019, 0.01935242, 0.35120681, 0.36533023],
#        [0.00051019, 0.01935242, 0.35120681, 0.36533023],
#        [0.00051019, 0.01935242, 0.35120681, 0.36533023],
#        [0.00051019, 0.01935242, 0.35120681, 0.36533023]]), array([-86843.08687336, -86337.82901505, -85921.79380891, -85780.05094742,
#        -85562.8261027 ]))
#            fun: -86843.08687335749
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 801
#            nit: 307
#         status: 1
#        success: False
#              x: array([0.00051019, 0.01935242, 0.35120681, 0.36533023])

# %%
final_simplex: (array([[0.00051019, 0.01935242, 0.35120681, 0.36533023],
       [0.00051019, 0.01935242, 0.35120681, 0.36533023],
       [0.00051019, 0.01935242, 0.35120681, 0.36533023],
       [0.00051019, 0.01935242, 0.35120681, 0.36533023],
       [0.00051019, 0.01935242, 0.35120681, 0.36533023]]), array([-86843.08687336, -86337.82901505, -85921.79380891, -85780.05094742,
       -85562.8261027 ]))
           fun: -86843.08687335749
       message: 'Maximum number of function evaluations has been exceeded.'
          nfev: 801
           nit: 307
        status: 1
       success: False
             x: array([0.00051019, 0.01935242, 0.35120681, 0.36533023])

# %%
[0.00051019, 0.01935242, 0.35120681, 0.36533023]

# %%
beta_1, beta_2, alpha, gamma = best.x

# %%
prep_data = model.data_and_network_prep()

# %%
best_params = {'beta_1': best.x[0], 'beta_2': best.x[1], 'alpha': best.x[2], 'gamma': best.x[3]}

# %%
# Create data for the fit
data_for_fit = model.create_data_for_fit(prep_data)

# Run the model
model_results = model.run_model(best_params, prep_data)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 181/181 [00:19<00:00,  9.08it/s]

# %%
log_like = model.log_likelihood(model_results['lambdas'], data_for_fit['data_for_fit'])
agg_log_like = model.log_likelihood_agg(model_results['lambdas_agg'], data_for_fit['infected_data_agg'])

print(f'log-liklihood: {int(log_like):,d}')
print(f'log-liklihood aggregated: {int(agg_log_like):,d}')
# Out:
# log-liklihood: -2,091,810
# log-liklihood aggregated: 86,115

# %%
model.plot_aggregated_fit(model_results, data_for_fit)

# %%
aa.plot_vacc_coverage(model_results, prep_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-fafb3988ff06> in <module>()
# ----> 1 aa.plot_vacc_coverage(model_results, prep_data)
#
# L:\Dor\Cellular-Database\Notebooks\model\vaccination_model.py in plot_vacc_coverage(model_results, prep_data)
#     462 def plot_vacc_coverage(model_results, prep_data):
#     463     # Get model coverage by clinic
# --> 464     model_coverage = get_vacc_coverage_by_clinic(model_results, prep_data).copy()
#     465     model_coverage.pop('total') # drop total
#     466     model_coverage = pd.DataFrame(pd.Series(model_coverage), columns=['model_coverage'])
#
# NameError: name 'vacc_coverage_by_clinic' is not defined
